# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.seasonal import STL
import scipy.stats
from sklearn.metrics import mean_squared_error, mean_absolute_error

import statsmodels.tsa.stattools as sts

from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

from time import time

# %% [markdown]
# # Processing

# %%
path = '../data/GOOGL_2006-01-01_to_2018-01-01.csv'
df = pd.read_csv(path)
df.head()
# Out:
#          Date    Open    High     Low   Close    Volume   Name
# 0  2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL
# 1  2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL
# 2  2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL
# 3  2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL
# 4  2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL

# %%
# Converting Date column to datetime
df['Date'] = pd.to_datetime(df.Date, yearfirst=True)
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume   Name
# 0 2006-01-03  211.47  218.05  209.32  217.83  13137450  GOOGL
# 1 2006-01-04  222.17  224.70  220.09  222.84  15292353  GOOGL
# 2 2006-01-05  223.22  226.00  220.97  225.85  10815661  GOOGL
# 3 2006-01-06  228.66  235.49  226.85  233.06  17759521  GOOGL
# 4 2006-01-09  233.44  236.94  230.70  233.68  12795837  GOOGL

# %%
df.set_index('Date', inplace=True) # Setting the index to date

df = df.asfreq('b') # Setting the frequency to business days

df.drop('Name', axis=1, inplace=True) # Dropping useless columns

# %% [markdown]
# # Checking clusters of NaN and filling NaN

# %%
# Create a boolean mask for NaN values
nan_mask = df['Open'].isna()

# Check for consecutive NaN values using the shift() function
consecutive_nan_mask = nan_mask & nan_mask.shift(-1)

consecutive_nan_mask.sum() # Checking how many consecutive nan there are
# Out:
# 3

# %%
df[(df.index.day < 5) * (df.index.month == 1) * (df.index.year == 2007)]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2007-01-01     NaN     NaN     NaN     NaN        NaN
# 2007-01-02     NaN     NaN     NaN     NaN        NaN
# 2007-01-03  233.23  238.57  230.79  234.03  7722839.0
# 2007-01-04  234.73  242.22  234.41  241.87  7916458.0

# %%
df[(df.index.day < 6) * (df.index.month == 4) * (df.index.year == 2010)]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2010-04-01     NaN     NaN     NaN     NaN        NaN
# 2010-04-02     NaN     NaN     NaN     NaN        NaN
# 2010-04-05  285.74  287.73  284.78  285.79  1902063.0

# %%
df[(df.index.day > 25) * (df.index.month == 10) * (df.index.year == 2012)]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2012-10-26  338.59  341.86  335.94  337.91  1950865.0
# 2012-10-29     NaN     NaN     NaN     NaN        NaN
# 2012-10-30     NaN     NaN     NaN     NaN        NaN
# 2012-10-31  340.27  340.84  337.84  340.49  1537001.0

# %%
df[consecutive_nan_mask]
# Out:
#             Open  High  Low  Close  Volume
# Date
# 2007-01-01   NaN   NaN  NaN    NaN     NaN
# 2010-04-01   NaN   NaN  NaN    NaN     NaN
# 2012-10-29   NaN   NaN  NaN    NaN     NaN

# %%
aux = df[consecutive_nan_mask]
df = df[~consecutive_nan_mask]

# %%
df = df.fillna(method='bfill') # Backfilling

# Adding the other samples
df = df.asfreq('b')
df = df.fillna(method='ffill') # Sampling them using frontfill

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
input_vars = df.shape[1]

# %% [markdown]
# # Normalization

# %%
train_size = 0.8
val_size = 0.1
train_samples = int(df.shape[0]*train_size)
val_samples = int(df.shape[0]*(train_size+val_size))

scaler = StandardScaler()
df.iloc[:train_samples] = scaler.fit_transform(df.iloc[:train_samples])
df.iloc[train_samples:] = scaler.transform(df.iloc[train_samples:])

# %%
df.head()
# Out:
#                 Open      High       Low     Close    Volume
# Date
# 2006-01-03 -0.904145 -0.873545 -0.899456 -0.854099  2.876012
# 2006-01-04 -0.821233 -0.822217 -0.815559 -0.815269  3.550220
# 2006-01-05 -0.813096 -0.812183 -0.808704 -0.791940  2.149591
# 2006-01-06 -0.770943 -0.738935 -0.762899 -0.736059  4.322127
# 2006-01-09 -0.733903 -0.727743 -0.732908 -0.731253  2.769132

# %% [markdown]
# # Lagging variables

# %%
n_lagged = 50

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    # n_in = number of lagged variables in the past
    # n_out = number of lagged variables in the future
    n_vars = 1 if type(data) is list else data.shape[1]
    df = data
    cols, names = list(), list()
    col_names = data.columns
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [(col_names[j]+'(t-%d)' % (i,)) for j in range(n_vars)]
        # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [col_names[j]+'(t)' for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# frame as supervised learning
reframed = series_to_supervised(df, n_lagged, 1)
# drop columns we don't want to predict
reframed.head()
# Out:
#             Open(t-50)  High(t-50)  Low(t-50)  Close(t-50)  Volume(t-50)  \
# Date
# 2006-03-14   -0.904145   -0.873545  -0.899456    -0.854099      2.876012
# 2006-03-15   -0.821233   -0.822217  -0.815559    -0.815269      3.550220
# 2006-03-16   -0.813096   -0.812183  -0.808704    -0.791940      2.149591
# 2006-03-17   -0.770943   -0.738935  -0.762899    -0.736059      4.322127
# 2006-03-20   -0.733903   -0.727743  -0.732908    -0.731253      2.769132
#
#             Open(t-49)  High(t-49)  Low(t-49)  Close(t-49)  Volume(t-49)  ...  \
# Date                                                                      ...
# 2006-03-14   -0.821233   -0.822217  -0.815559    -0.815269      3.550220  ...
# 2006-03-15   -0.813096   -0.812183  -0.808704    -0.791940      2.149591  ...
# 2006-03-16   -0.770943   -0.738935  -0.762899    -0.736059      4.322127  ...
# 2006-03-17   -0.733903   -0.727743  -0.732908    -0.731253      2.769132  ...
# 2006-03-20   -0.741652   -0.739938  -0.728624    -0.720170      1.614286  ...
#
#             Open(t-1)  High(t-1)  Low(t-1)  Close(t-1)  Volume(t-1)   Open(t)  \
# Date
# 2006-03-14  -1.220530  -1.219563 -1.222191   -1.234880     3.035635 -1.235253
# 2006-03-15  -1.235253  -1.195327 -1.233175   -1.180162     4.542192 -1.182406
# 2006-03-16  -1.182406  -1.195558 -1.202327   -1.206048     2.761922 -1.190775
# 2006-03-17  -1.190775  -1.209297 -1.212609   -1.228292     1.901114 -1.228821
# 2006-03-20  -1.228821  -1.236235 -1.224216   -1.224339     1.443441 -1.215106
#
#              High(t)    Low(t)  Close(t)  Volume(t)
# Date
# 2006-03-14 -1.195327 -1.233175 -1.180162   4.542192
# 2006-03-15 -1.195558 -1.202327 -1.206048   2.761922
# 2006-03-16 -1.209297 -1.212609 -1.228292   1.901114
# 2006-03-17 -1.236235 -1.224216 -1.224339   1.443441
# 2006-03-20 -1.204126 -1.198432 -1.191710   2.024490
#
# [5 rows x 255 columns]

# %%
# At time "t", we only have Open(t) and want to predict Close(t), so we can drop High(t), Volume(t) and Low(t)
# Also we will drop Open(t-1) because each time step needs to have exactly 4 variables. If we add more time steps we will have
# a remaining Variable (Open(t)) to spare, so we will replace Open(t-1) with Open(t) for the first lagged variable.
reframed.drop(['High(t)', 'Low(t)', 'Volume(t)', 'Open(t-1)'], axis=1, inplace=True)
reframed.head()
# Out:
#             Open(t-50)  High(t-50)  Low(t-50)  Close(t-50)  Volume(t-50)  \
# Date
# 2006-03-14   -0.904145   -0.873545  -0.899456    -0.854099      2.876012
# 2006-03-15   -0.821233   -0.822217  -0.815559    -0.815269      3.550220
# 2006-03-16   -0.813096   -0.812183  -0.808704    -0.791940      2.149591
# 2006-03-17   -0.770943   -0.738935  -0.762899    -0.736059      4.322127
# 2006-03-20   -0.733903   -0.727743  -0.732908    -0.731253      2.769132
#
#             Open(t-49)  High(t-49)  Low(t-49)  Close(t-49)  Volume(t-49)  ...  \
# Date                                                                      ...
# 2006-03-14   -0.821233   -0.822217  -0.815559    -0.815269      3.550220  ...
# 2006-03-15   -0.813096   -0.812183  -0.808704    -0.791940      2.149591  ...
# 2006-03-16   -0.770943   -0.738935  -0.762899    -0.736059      4.322127  ...
# 2006-03-17   -0.733903   -0.727743  -0.732908    -0.731253      2.769132  ...
# 2006-03-20   -0.741652   -0.739938  -0.728624    -0.720170      1.614286  ...
#
#             High(t-2)  Low(t-2)  Close(t-2)  Volume(t-2)  High(t-1)  Low(t-1)  \
# Date
# 2006-03-14  -1.225738 -1.237381   -1.233175     4.815238  -1.219563 -1.222191
# 2006-03-15  -1.219563 -1.222191   -1.234880     3.035635  -1.195327 -1.233175
# 2006-03-16  -1.195327 -1.233175   -1.180162     4.542192  -1.195558 -1.202327
# 2006-03-17  -1.195558 -1.202327   -1.206048     2.761922  -1.209297 -1.212609
# 2006-03-20  -1.209297 -1.212609   -1.228292     1.901114  -1.236235 -1.224216
#
#             Close(t-1)  Volume(t-1)   Open(t)  Close(t)
# Date
# 2006-03-14   -1.234880     3.035635 -1.235253 -1.180162
# 2006-03-15   -1.180162     4.542192 -1.182406 -1.206048
# 2006-03-16   -1.206048     2.761922 -1.190775 -1.228292
# 2006-03-17   -1.228292     1.901114 -1.228821 -1.224339
# 2006-03-20   -1.224339     1.443441 -1.215106 -1.191710
#
# [5 rows x 251 columns]

# %% [markdown]
# # Data splitting

# %%
train_X, train_y = reframed.iloc[:train_samples, :-1].values, reframed.iloc[:train_samples, -1].values
val_X, val_y = reframed.iloc[train_samples:val_samples, :-1].values, reframed.iloc[train_samples:val_samples, -1].values
test_X, test_y = reframed.iloc[val_samples:, :-1].values, reframed.iloc[val_samples:, -1].values

# %% [markdown]
# # Reshaping data for LSTM

# %%
train_X = train_X.reshape((train_X.shape[0], n_lagged, input_vars))
val_X = val_X.reshape((val_X.shape[0], n_lagged, input_vars))
test_X = test_X.reshape((test_X.shape[0], n_lagged, input_vars))

# %%
train_X.shape
# Out:
# (2503, 50, 5)

# %% [markdown]
# # LSTM

# %%
hidden_layer_neurons = 500
batch_size = 32
epochs = 100
learning_rate = 0.0005

# Optimizer and callbacks
optimizer = Adam(learning_rate=learning_rate)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


# Defining model
model = Sequential()
model.add(LSTM(hidden_layer_neurons, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1)) # Output layer
model.compile(loss='mse', optimizer=optimizer)

# Fit network
t0 = time.time()
history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, 
                    validation_data=(val_X, val_y), verbose=2, shuffle=False,
                   callbacks = [early_stopping])
t1 = time.time()
print("Total execution time:", t1-t0)

# Plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 79/79 - 10s - loss: 0.0492 - val_loss: 0.0295 - 10s/epoch - 121ms/step
# Epoch 2/100
# 79/79 - 7s - loss: 0.0142 - val_loss: 0.0217 - 7s/epoch - 91ms/step
# Epoch 3/100
# 79/79 - 7s - loss: 0.0092 - val_loss: 0.0170 - 7s/epoch - 92ms/step
# Epoch 4/100
# 79/79 - 8s - loss: 0.0073 - val_loss: 0.0151 - 8s/epoch - 106ms/step
# Epoch 5/100
# 79/79 - 8s - loss: 0.0066 - val_loss: 0.0147 - 8s/epoch - 101ms/step
# Epoch 6/100
# 79/79 - 8s - loss: 0.0060 - val_loss: 0.0140 - 8s/epoch - 102ms/step
# Epoch 7/100
# 79/79 - 11s - loss: 0.0056 - val_loss: 0.0136 - 11s/epoch - 135ms/step
# Epoch 8/100
# 79/79 - 10s - loss: 0.0053 - val_loss: 0.0132 - 10s/epoch - 123ms/step
# Epoch 9/100
# 79/79 - 10s - loss: 0.0051 - val_loss: 0.0129 - 10s/epoch - 128ms/step
# Epoch 10/100
# 79/79 - 11s - loss: 0.0049 - val_loss: 0.0126 - 11s/epoch - 136ms/step
# Epoch 11/100
# 79/79 - 11s - loss: 0.0049 - val_loss: 0.0121 - 11s/epoch - 135ms/step
# Epoch 12/100
# 79/79 - 10s - loss: 0.0049 - val_loss: 0.0112 - 10s/epoch - 126ms/step
# Epoch 13/100
# 79/79 - 10s - loss: 0.0050 - val_loss: 0.0119 - 10s/epoch - 128ms/step
# Epoch 14/100
# 79/79 - 10s - loss: 0.0049 - val_loss: 0.0103 - 10s/epoch - 123ms/step
# Epoch 15/100
# 79/79 - 10s - loss: 0.0049 - val_loss: 0.0086 - 10s/epoch - 126ms/step
# Epoch 16/100
# 79/79 - 10s - loss: 0.0045 - val_loss: 0.0123 - 10s/epoch - 124ms/step
# Epoch 17/100
# 79/79 - 10s - loss: 0.0041 - val_loss: 0.0077 - 10s/epoch - 130ms/step
# Epoch 18/100
# 79/79 - 11s - loss: 0.0034 - val_loss: 0.0071 - 11s/epoch - 134ms/step
# Epoch 19/100
# 79/79 - 10s - loss: 0.0032 - val_loss: 0.0068 - 10s/epoch - 123ms/step
# Epoch 20/100
# 79/79 - 10s - loss: 0.0032 - val_loss: 0.0066 - 10s/epoch - 128ms/step
# Epoch 21/100
# 79/79 - 10s - loss: 0.0030 - val_loss: 0.0063 - 10s/epoch - 122ms/step
# Epoch 22/100
# 79/79 - 10s - loss: 0.0030 - val_loss: 0.0061 - 10s/epoch - 120ms/step
# Epoch 23/100
# 79/79 - 10s - loss: 0.0030 - val_loss: 0.0060 - 10s/epoch - 123ms/step
# Epoch 24/100
# 79/79 - 10s - loss: 0.0030 - val_loss: 0.0059 - 10s/epoch - 126ms/step
# Epoch 25/100
# 79/79 - 10s - loss: 0.0029 - val_loss: 0.0058 - 10s/epoch - 123ms/step
# Epoch 26/100
# 79/79 - 10s - loss: 0.0029 - val_loss: 0.0056 - 10s/epoch - 121ms/step
# Epoch 27/100
# 79/79 - 10s - loss: 0.0028 - val_loss: 0.0055 - 10s/epoch - 123ms/step
# Epoch 28/100
# 79/79 - 10s - loss: 0.0028 - val_loss: 0.0054 - 10s/epoch - 122ms/step
# Epoch 29/100
# 79/79 - 10s - loss: 0.0027 - val_loss: 0.0053 - 10s/epoch - 122ms/step
# Epoch 30/100
# 79/79 - 10s - loss: 0.0027 - val_loss: 0.0052 - 10s/epoch - 123ms/step
# Epoch 31/100
# 79/79 - 9s - loss: 0.0027 - val_loss: 0.0052 - 9s/epoch - 119ms/step
# Epoch 32/100
# 79/79 - 10s - loss: 0.0026 - val_loss: 0.0051 - 10s/epoch - 120ms/step
# Epoch 33/100
# 79/79 - 9s - loss: 0.0025 - val_loss: 0.0050 - 9s/epoch - 120ms/step
# Epoch 34/100
# 79/79 - 11s - loss: 0.0025 - val_loss: 0.0049 - 11s/epoch - 140ms/step
# Epoch 35/100
# 79/79 - 10s - loss: 0.0024 - val_loss: 0.0048 - 10s/epoch - 121ms/step
# Epoch 36/100
# 79/79 - 11s - loss: 0.0024 - val_loss: 0.0047 - 11s/epoch - 134ms/step
# Epoch 37/100
# 79/79 - 10s - loss: 0.0024 - val_loss: 0.0047 - 10s/epoch - 131ms/step
# Epoch 38/100
# 79/79 - 10s - loss: 0.0023 - val_loss: 0.0046 - 10s/epoch - 126ms/step
# Epoch 39/100
# 79/79 - 11s - loss: 0.0023 - val_loss: 0.0046 - 11s/epoch - 138ms/step
# Epoch 40/100
# 79/79 - 14s - loss: 0.0023 - val_loss: 0.0046 - 14s/epoch - 171ms/step
# Epoch 41/100
# 79/79 - 11s - loss: 0.0023 - val_loss: 0.0047 - 11s/epoch - 141ms/step
# Epoch 42/100
# 79/79 - 11s - loss: 0.0023 - val_loss: 0.0047 - 11s/epoch - 144ms/step
# Epoch 43/100
# 79/79 - 12s - loss: 0.0022 - val_loss: 0.0047 - 12s/epoch - 157ms/step
# Epoch 44/100
# 79/79 - 11s - loss: 0.0022 - val_loss: 0.0047 - 11s/epoch - 145ms/step
# Epoch 45/100
# 79/79 - 11s - loss: 0.0021 - val_loss: 0.0046 - 11s/epoch - 138ms/step
# Epoch 46/100
# 79/79 - 11s - loss: 0.0021 - val_loss: 0.0045 - 11s/epoch - 139ms/step
# Epoch 47/100
# 79/79 - 12s - loss: 0.0020 - val_loss: 0.0045 - 12s/epoch - 148ms/step
# Epoch 48/100
# 79/79 - 13s - loss: 0.0023 - val_loss: 0.0046 - 13s/epoch - 162ms/step
# Epoch 49/100
# 79/79 - 10s - loss: 0.0021 - val_loss: 0.0046 - 10s/epoch - 133ms/step
# Epoch 50/100
# 79/79 - 10s - loss: 0.0023 - val_loss: 0.0050 - 10s/epoch - 130ms/step
# Epoch 51/100
# 79/79 - 11s - loss: 0.0022 - val_loss: 0.0058 - 11s/epoch - 140ms/step
# Epoch 52/100
# 79/79 - 10s - loss: 0.0025 - val_loss: 0.0078 - 10s/epoch - 123ms/step
# Epoch 53/100
# 79/79 - 10s - loss: 0.0023 - val_loss: 0.0046 - 10s/epoch - 125ms/step
# Epoch 54/100
# 79/79 - 10s - loss: 0.0022 - val_loss: 0.0045 - 10s/epoch - 130ms/step
# Epoch 55/100
# 79/79 - 10s - loss: 0.0022 - val_loss: 0.0046 - 10s/epoch - 121ms/step
# Epoch 56/100
# 79/79 - 10s - loss: 0.0024 - val_loss: 0.0046 - 10s/epoch - 127ms/step
# Epoch 57/100
# 79/79 - 10s - loss: 0.0021 - val_loss: 0.0046 - 10s/epoch - 124ms/step

# %% [markdown]
# # Predicting

# %%
mean = scaler.mean_[scaler.feature_names_in_ == 'Close'][0]
std = np.sqrt(scaler.var_[scaler.feature_names_in_ == 'Close'][0])

# %%
plt.subplots(figsize=(10, 5))

# make a prediction
yhat_train = model.predict(train_X).flatten()
yhat_val = model.predict(val_X).flatten() 
yhat_test = model.predict(test_X).flatten() 

# Concatenate the results
y_pred = np.concatenate([yhat_train, yhat_val, yhat_test])* std + mean
y_real = np.concatenate([train_y, val_y, test_y]) * std + mean

# Plot
plt.plot(df.iloc[n_lagged:].index, y_pred, label='Predicted')
plt.plot(df.iloc[n_lagged:].index, y_real, label='Real')

plt.axvline(x = df.iloc[[train_samples]].index, color = 'yellow', label = 'Validation')
plt.axvline(x = df.iloc[[val_samples]].index, color = 'red', label = 'Test')

plt.legend()
plt.xlabel("Date")
plt.ylabel("Closing Stock price")
plt.title("LSTM Results")
plt.show()
# Out:
# 79/79 [==============================] - 4s 39ms/step
# 10/10 [==============================] - 0s 42ms/step
# 9/9 [==============================] - 0s 40ms/step

# %%
# Getting metrics
# MSE
train_rmse = np.sqrt( mean_squared_error( y_real[:train_samples], y_pred[:train_samples] ) )
val_rmse = np.sqrt( mean_squared_error( y_real[train_samples:val_samples], y_pred[train_samples:val_samples] ) )
test_rmse = np.sqrt( mean_squared_error( y_real[val_samples:], y_pred[val_samples:] ) )

# MAE
train_mae = mean_absolute_error( y_real[:train_samples], y_pred[:train_samples] )
val_mae = mean_absolute_error( y_real[train_samples:val_samples], y_pred[train_samples:val_samples] )
test_mae = mean_absolute_error( y_real[val_samples:], y_pred[val_samples:] )

# %%
test_mae
# Out:
# 11.893546082239189
